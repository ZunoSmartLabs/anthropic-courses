# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (0.116.0)
# Requirement already satisfied: python-dotenv in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/sebkueger/code/github.com/zunosmartlabs/anthropic-courses/building_with_claude_api/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API clients
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return next(block.text for block in message.content if block.type == "text")

# %%
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Exit the loop when the user types 'quit'
    if user_input.lower() == "quit":
        break

    # Add user input to the list of messages
    add_user_message(messages, user_input)
    # Call Claude with the Messages API
    answer = chat(messages)
    # Add generated text to the list of messages
    add_assistant_message(messages, answer)
    # Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > what's 1+1?
# ---
# **1 + 1 = 2**
#
# This is basic arithmetic addition: combining one unit with another unit gives you a total of two units.
# ---
# > add 2 to that answer
# ---
# **2 + 2 = 4**
#
# Adding 2 to the previous answer (2) gives you 4.
# ---
# > quit
